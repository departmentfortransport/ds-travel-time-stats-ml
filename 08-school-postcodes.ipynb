# %% [markdown]
# School data is available on the [DfE](https://www.compare-school-performance.service.gov.uk/) website that includes the postcode for each school.
# We can convert a postcode to lat-lon using the free api [Postcodes.io](https://postcodes.io/)
# We can then use lat-lon of the postcodes and the LSOA midpoint to measure the closest distance to a school and add it  as variavble in the machine learning. Hopefully greatly improving model accuracy.
#
# The API would take a while to install. It uses data from ONS available online [here](https://data.gov.uk/dataset/national-statistics-postcode-lookup-uk)

# %% [markdown]
# ## Download DfE data

# %%
import pandas as pd
import numpy as np


url_2015 = 'https://www.compare-school-performance.service.gov.uk/download-data?download=true&regions=0&filters=SPINE&fileformat=csv&year=2014-2015&meta=false'
url_2014 = 'https://www.compare-school-performance.service.gov.uk/download-data?download=true&regions=0&filters=SPINE&fileformat=csv&year=2013-2014&meta=false'

save_as_2015 = 'open-data/schools-v2-2015.csv'
save_as_2014 = 'open-data/schools-v2-2014.csv'

# %% [markdown]
# Cannot download in python. Do it manually

# %% [markdown]
# ## Download postcode data

# %% [markdown]
# Manually download the csv from [https://data.gov.uk/dataset/national-statistics-postcode-lookup-uk](https://data.gov.uk/dataset/national-statistics-postcode-lookup-uk) and save as 'open-data/postcodes.csv

# %%
df_postcodes = pd.read_csv('open-data/postcodes.csv')

# %%
df_postcodes['Postcode 1'] = df_postcodes['Postcode 1'].apply(lambda x: x.upper().replace(' ', ''))
df_postcodes['Postcode 2'] = df_postcodes['Postcode 1'].apply(lambda x: x.upper().replace(' ', ''))
df_postcodes['Postcode 3'] = df_postcodes['Postcode 1'].apply(lambda x: x.upper().replace(' ', ''))
p1 = df_postcodes.drop(['Postcode 2', 'Postcode 3'], axis=1).rename(columns={'Postcode 1': 'POSTCODE'})
p2 = df_postcodes.drop(['Postcode 1', 'Postcode 3'], axis=1).rename(columns={'Postcode 2': 'POSTCODE'})
p3 = df_postcodes.drop(['Postcode 1', 'Postcode 2'], axis=1).rename(columns={'Postcode 3': 'POSTCODE'})
df_postcodes_long = pd.concat([p1, p2, p3], axis = 0, ignore_index=True)

# %%
df_postcodes_long = df_postcodes_long[['POSTCODE','Lower Super Output Area Code',
                            'Longitude', 'Latitude']].drop_duplicates()
df_postcodes_long = df_postcodes_long[df_postcodes_long['Lower Super Output Area Code'].isnull() == False]

# %%
df_postcodes_long.head()
# Out:
#   POSTCODE Lower Super Output Area Code  Longitude   Latitude
# 0   S206RU                    E01008038  -1.379193  53.340953
# 1   TW47BD                    E01002660  -0.383652  51.466899
# 2  GU513ZQ                    E01022870  -0.831674  51.288637
# 3   OX46BE                    E01028518  -1.198788  51.723313
# 4   TA79JH                    E01029150  -2.877144  51.149999

# %%
df_postcodes_long.shape
# Out:
# (1755145, 4)

# %% [markdown]
# ### Merge the two datasets on the postcodes

# %%
def school_by_lsoa(year):
    if year == 2014:
        file = save_as_2014
    if year == 2015:
        file = save_as_2015
    
    df_schools = pd.read_csv(file)
    df_schools = df_schools[['URN', 'SCHNAME', 'POSTCODE', 'ISPRIMARY', 'ISSECONDARY', 'ISPOST16']]
    df_schools = df_schools[df_schools.POSTCODE.isnull() == False]
    df_schools['POSTCODE'] = df_schools['POSTCODE'].apply(lambda x: x.upper().replace(' ', ''))
    merged = df_schools.merge(df_postcodes_long, how='left', on='POSTCODE')
    not_merged = merged['Lower Super Output Area Code'].isnull().sum() / len(merged)
    print('Percent of schools were the LSOA could not be determined from the postcode')
    print('{:.2f}'.format(not_merged*100) + '%')
    merged['year'] = year
    return(merged)

# %%
df_2014 = school_by_lsoa(2014)
df_2015 = school_by_lsoa(2015)
df = pd.concat([df_2014, df_2015], ignore_index = False).rename(columns={'Lower Super Output Area Code': 'LSOA_code'})
secondary = df[df.ISSECONDARY == 1]
primary = df[df.ISPRIMARY == 1]
post16 = df[df.ISPOST16 == 1]
# Out:
# Percent of schools were the LSOA could not be determined from the postcode
# 0.54%
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Percent of schools were the LSOA could not be determined from the postcode
# 0.37%

# %%
secondary = secondary.groupby(['year', 'LSOA_code']).size().reset_index(name='schools_secondary')
primary = primary.groupby(['year', 'LSOA_code']).size().reset_index(name='schools_primary')
post16 = post16.groupby(['year', 'LSOA_code']).size().reset_index(name='schools_post16')

# %%
df = primary.merge(secondary).merge(post16)

# %% [markdown]
# ## Codes are 2001. Convert to 2011
# Download Data
# http://geoportal.statistics.gov.uk/datasets?q=Lower%20Layer%20Super%20Output%20Area%20(2001)%20to%20Lower%20Layer%20Super%20Output%20Area%20(2011)%20to%20Local%20Authority%20District%20(2011)%20Lookup&sort=name

# %%
lsoa_lookup = pd.read_csv('open-data/LSOA01_to_LSOA11.csv', encoding = 'latin')

# %%
lsoa_lookup.sort_values('LSOA11CD').head()
# Out:
#        LSOA01CD                   LSOA01NM   LSOA11CD  \
# 7397  E01000001        City of London 001A  E01000001
# 7398  E01000002        City of London 001B  E01000002
# 7399  E01000003        City of London 001C  E01000003
# 7400  E01000005        City of London 001E  E01000005
# 666   E01000006  Barking and Dagenham 016A  E01000006
#
#                        LSOA11NM CHGIND    LAD11CD               LAD11NM  \
# 7397        City of London 001A      U  E09000001        City of London
# 7398        City of London 001B      U  E09000001        City of London
# 7399        City of London 001C      U  E09000001        City of London
# 7400        City of London 001E      U  E09000001        City of London
# 666   Barking and Dagenham 016A      U  E09000002  Barking and Dagenham
#
#      LAD11NMW
# 7397      NaN
# 7398      NaN
# 7399      NaN
# 7400      NaN
# 666       NaN

# %%
df = df.merge(lsoa_lookup, how='left', left_on='LSOA_code', right_on='LSOA01CD')

# %%
df_2011_zones = df.groupby(['year', 'LSOA11CD' ])[['schools_primary', 'schools_secondary', 'schools_post16' ]].sum().reset_index()
df_2011_zones = df_2011_zones.rename(columns={'LSOA11CD': 'LSOA_code'})

# %%
df_2011_zones.head()
# Out:
#    year  LSOA_code  schools_primary  schools_secondary  schools_post16
# 0  2014  E01000002                1                  1               1
# 1  2014  E01000010                3                  1               1
# 2  2014  E01000056                1                  1               1
# 3  2014  E01000065                2                  1               1
# 4  2014  E01000066                2                  1               1

# %% [markdown]
# ## Join the new data onto the existing lot

# %%
df_old = pd.read_csv('02-enriched-data.csv')

# %%
df_new = df_old.merge(df_2011_zones, how='left', on=['LSOA_code', 'year'])

# %%
df_new.schools_secondary.isnull().sum() / len(df_new)
# Out:
# 0.93210327609304588

# %%
city_of_london_lsoa = 'E01000001'
city_of_london_lsoa in df.LSOA_code
# Out:
# False

# %%
df_new[df_new.schools_primary.isnull() == False]
# Out:
#          LSOA_code         Region    LA_Code         LA_Name  year  \
# 48       E01000002         London  E09000001  City of London  2014
# 49       E01000002         London  E09000001  City of London  2014
# 50       E01000002         London  E09000001  City of London  2014
# 51       E01000002         London  E09000001  City of London  2015
# 52       E01000002         London  E09000001  City of London  2015
# 53       E01000002         London  E09000001  City of London  2015
# 54       E01000002         London  E09000001  City of London  2015
# 55       E01000002         London  E09000001  City of London  2014
# 56       E01000002         London  E09000001  City of London  2015
# 57       E01000002         London  E09000001  City of London  2014
# 58       E01000002         London  E09000001  City of London  2015
# 59       E01000002         London  E09000001  City of London  2014
# 60       E01000002         London  E09000001  City of London  2015
# 61       E01000002         London  E09000001  City of London  2014
# 62       E01000002         London  E09000001  City of London  2015
# 63       E01000002         London  E09000001  City of London  2014
# 64       E01000002         London  E09000001  City of London  2015
# 65       E01000002         London  E09000001  City of London  2014
# 66       E01000002         London  E09000001  City of London  2015
# 67       E01000002         London  E09000001  City of London  2014
# 68       E01000002         London  E09000001  City of London  2015
# 69       E01000002         London  E09000001  City of London  2014
# 70       E01000002         London  E09000001  City of London  2015
# 71       E01000002         London  E09000001  City of London  2014
# 72       E01000002         London  E09000001  City of London  2015
# 73       E01000002         London  E09000001  City of London  2014
# 74       E01000002         London  E09000001  City of London  2015
# 75       E01000002         London  E09000001  City of London  2014
# 76       E01000002         London  E09000001  City of London  2015
# 77       E01000002         London  E09000001  City of London  2014
# ...            ...            ...        ...             ...   ...
# 1520226  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520227  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520228  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520229  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520230  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520231  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520232  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520233  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520234  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520235  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520236  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520237  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520238  E01032482  West Midlands  E07000239     Wyre Forest  2015
# 1520239  E01032482  West Midlands  E07000239     Wyre Forest  2014
# 1520246             cycle     7.199179               food
# 1520247             cycle     7.482450               food
# 1520248               car     6.401620               food
# 1520249               car     6.642557               food
# 1520250  public transport     9.544949        town_centre
# 1520251  public transport     9.523558        town_centre
# 1520252             cycle     8.062757        town_centre
# 1520253             cycle     8.069114        town_centre
# 1520254               car     6.682001        town_centre
# 1520255               car     6.756379        town_centre
#
#                      urban_rural  area_square_km       ...        \
# 48       Urban major conurbation          0.2284       ...
# 49       Urban major conurbation          0.2284       ...
# 50       Urban major conurbation          0.2284       ...
# 51       Urban major conurbation          0.2284       ...
# 52       Urban major conurbation          0.2284       ...
# 53       Urban major conurbation          0.2284       ...
# 54       Urban major conurbation          0.2284       ...
# 55       Urban major conurbation          0.2284       ...
# 56       Urban major conurbation          0.2284       ...
# 57       Urban major conurbation          0.2284       ...
# 58       Urban major conurbation          0.2284       ...
# 59       Urban major conurbation          0.2284       ...
# 60       Urban major conurbation          0.2284       ...
# 61       Urban major conurbation          0.2284       ...
# 62       Urban major conurbation          0.2284       ...
# 63       Urban major conurbation          0.2284       ...
# 64       Urban major conurbation          0.2284       ...
# 65       Urban major conurbation          0.2284       ...
# 66       Urban major conurbation          0.2284       ...
# 67       Urban major conurbation          0.2284       ...
# 68       Urban major conurbation          0.2284       ...
# 69       Urban major conurbation          0.2284       ...
# 70       Urban major conurbation          0.2284       ...
# 71       Urban major conurbation          0.2284       ...
# 72       Urban major conurbation          0.2284       ...
# 73       Urban major conurbation          0.2284       ...
# 74       Urban major conurbation          0.2284       ...
# 75       Urban major conurbation          0.2284       ...
# 76       Urban major conurbation          0.2284       ...
# 77       Urban major conurbation          0.2284       ...
# ...                          ...             ...       ...
# 1520226    Rural town and fringe          0.7585       ...
# 1520227    Rural town and fringe          0.7585       ...
# 1520228    Rural town and fringe          0.7585       ...
# 1520229    Rural town and fringe          0.7585       ...
# 1520230    Rural town and fringe          0.7585       ...
# 1520231    Rural town and fringe          0.7585       ...
# 1520232    Rural town and fringe          0.7585       ...
# 1520233    Rural town and fringe          0.7585       ...
# 1520234    Rural town and fringe          0.7585       ...
# 1520235    Rural town and fringe          0.7585       ...
# 1520236    Rural town and fringe          0.7585       ...
# 1520237    Rural town and fringe          0.7585       ...
# 1520238    Rural town and fringe          0.7585       ...
# 1520239    Rural town and fringe          0.7585       ...
# 1520240    Rural town and fringe          0.7585       ...
# 1520241    Rural town and fringe          0.7585       ...
# 1520242    Rural town and fringe          0.7585       ...
# 1520243    Rural town and fringe          0.7585       ...
# 1520244    Rural town and fringe          0.7585       ...
# 1520245    Rural town and fringe          0.7585       ...
# 1520246    Rural town and fringe          0.7585       ...
# 1520247    Rural town and fringe          0.7585       ...
# 1520248    Rural town and fringe          0.7585       ...
# 1520249    Rural town and fringe          0.7585       ...
# 1520250    Rural town and fringe          0.7585       ...
# 1520251    Rural town and fringe          0.7585       ...
# 1520252    Rural town and fringe          0.7585       ...
# 1520253    Rural town and fringe          0.7585       ...
# 1520248                    45              1.0                1.0
# 1520249                    45              1.0                1.0
# 1520250                    45              1.0                1.0
# 1520251                    45              1.0                1.0
# 1520252                    45              1.0                1.0
# 1520253                    45              1.0                1.0
# 1520254                    45              1.0                1.0
# 1520255                    45              1.0                1.0
#
#          schools_post16
# 48                  1.0
# 49                  1.0
# 50                  1.0
# 51                  1.0
# 52                  1.0
# 53                  1.0
# 54                  1.0
# 55                  1.0
# 56                  1.0
# 57                  1.0
# 58                  1.0
# 59                  1.0
# 60                  1.0
# 61                  1.0
# 62                  1.0
# 63                  1.0
# 64                  1.0
# 65                  1.0
# 66                  1.0
# 67                  1.0
# 68                  1.0
# 69                  1.0
# 70                  1.0
# 71                  1.0
# 72                  1.0
# 73                  1.0
# 74                  1.0
# 75                  1.0
# 76                  1.0
# 77                  1.0
# ...                 ...
# 1520226             1.0
# 1520227             1.0
# 1520228             1.0
# 1520229             1.0
# 1520230             1.0
# 1520231             1.0
# 1520232             1.0
# 1520233             1.0
# 1520234             1.0
# 1520235             1.0
# 1520236             1.0
# 1520237             1.0
# 1520238             1.0
# 1520239             1.0
# 1520240             1.0
# 1520241             1.0
# 1520242             1.0
# 1520243             1.0
# 1520244             1.0
# 1520245             1.0
# 1520246             1.0
# 1520247             1.0
# 1520248             1.0
# 1520249             1.0
# 1520250             1.0
# 1520251             1.0
# 1520252             1.0
# 1520253             1.0
# 1520254             1.0
# 1520255             1.0
#
# [107040 rows x 26 columns]

# %%
df_new.head()
# Out:
#    LSOA_code  Region    LA_Code         LA_Name  year              mode  \
# 0  E01000001  London  E09000001  City of London  2014               car
# 1  E01000001  London  E09000001  City of London  2014             cycle
# 2  E01000001  London  E09000001  City of London  2014  public transport
# 3  E01000001  London  E09000001  City of London  2015               car
# 4  E01000001  London  E09000001  City of London  2015             cycle
#
#    travel_time            nearest              urban_rural  area_square_km  \
# 0     6.753080  employment_centre  Urban major conurbation          0.1298
# 1     6.610821  employment_centre  Urban major conurbation          0.1298
# 2     3.648643  employment_centre  Urban major conurbation          0.1298
# 3     6.153411  employment_centre  Urban major conurbation          0.1298
# 4     6.501751  employment_centre  Urban major conurbation          0.1298
#
#         ...        road_LA_trunk_length_km  bus_LA_vehicle_km_travelled  \
# 0       ...                            0.0                    14.730303
# 1       ...                            0.0                    14.730303
# 2       ...                            0.0                    14.730303
# 3       ...                            0.0                    14.696970
# 4       ...                            0.0                    14.696970
#
#    schools_all_LA  schools_nursery_LA  schools_primary_LA  schools_private_LA  \
# 0               5                   0                   1                   4
# 1               5                   0                   1                   4
# 2               5                   0                   1                   4
# 3               5                   0                   1                   4
# 4               5                   0                   1                   4
#
#    schools_secondary_LA  schools_primary  schools_secondary  schools_post16
# 0                     0              NaN                NaN             NaN
# 1                     0              NaN                NaN             NaN
# 2                     0              NaN                NaN             NaN
# 3                     0              NaN                NaN             NaN
# 4                     0              NaN                NaN             NaN
#
# [5 rows x 26 columns]
