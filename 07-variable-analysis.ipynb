# %%
import pandas as pd
import seaborn as sns
import numpy as np

% matplotlib inline

# %%
df = pd.read_csv('05-transformed-data.csv')
df_reduced = df[np.random.random(len(df)) < 0.01]
df.columns
# Out:
# Index(['Unnamed: 0', 'travel_time', 'area_square_km', 'pop_u18',
#        'pop_working_age', 'pop_retired_age', 'road_LA_minor_length_km',
#        'road_LA_principal_length_km', 'road_LA_total_length_km',
#        'road_LA_trunk_length_km', 'bus_LA_vehicle_km_travelled',
#        'schools_all_LA', 'schools_nursery_LA', 'schools_primary_LA',
#        'schools_private_LA', 'schools_secondary_LA', 'pop_all',
#        'area_square_km_LA', 'pop_all_LA', 'pop_u18_LA', 'pop_density',
#        'pop_density_LA', 'children_density', 'children_density_LA',
#        'road_density_LA', 'school_density_LA', 'bus_km_per_pop_LA',
#        'bus_km_per_road_km_LA', 'bus_per_pop_LA', 'Region_is_London',
#        'Region_is_North West', 'Region_is_Yorkshire and The Humber',
#        'Region_is_North East', 'Region_is_West Midlands',
#        'Region_is_East Midlands', 'Region_is_South West', 'Region_is_East',
#        'Region_is_South East', 'mode_is_car', 'mode_is_cycle',
# ...

# %%
df.shape
# Out:
# (591192, 52)

# %%
sns.jointplot(x=np.log(df_reduced.pop_density), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.area_square_km), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.pop_retired_age), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.children_density), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.children_density_LA), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.bus_km_per_road_km_LA), y=np.log(df_reduced.travel_time+1))

# %%
sns.jointplot(x=np.log(df_reduced.road_LA_trunk_length_km+1), y=np.log(df_reduced.travel_time+1))
