# %% [markdown]
# ## Purpose
#
# Travel time statistics are published on the [DfT stats page](https://www.gov.uk/government/collections/journey-time-statistics).  Minimum journey times to a variety of services at each [LSOA](http://webarchive.nationalarchives.gov.uk/20160106001702/http://www.ons.gov.uk/ons/guide-method/geography/beginner-s-guide/census/super-output-areas--soas-/index.html) are contained within a handfull of ODS spreadsheets. Each file contains sheets for different years and is in a wide format with non human readable column names.
# This notebook demonstrates:
#
# * Downloading the spreadsheets
# * Saving the data to a pandas dataframe
# * Renaming the variables and converting to a single table in the long data format (one row per observation).

# %% [markdown]
# ### Download the files

# %%
import os
import requests 
import shutil
import pyexcel
import pandas as pd
import numpy as np

# Create folder to store data in, if it doesn't already exist
if os.path.isdir('stats-spreadsheets') == False:
    os.mkdir('stats-spreadsheets')

# %%
def download_data():   
    urls = {
        'employment': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627362/jts0501.ods',
        'primary schools': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627363/jts0502.ods',
        'secondary schools': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627365/jts0503.ods',
        'further education': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627366/jts0504.ods',
        'GP': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627367/jts0505.ods',
        'hospital': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627369/jts0506.ods',
        'food': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627370/jts0507.ods',
        'town centre': 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/627371/jts0508.ods'
    }

    for key, url in urls.items():
        r = requests.get(url, stream=True)
        if r.status_code == 200:
            with open('stats-spreadsheets/' + key + '.ods', 'wb') as out_file:
                shutil.copyfileobj(r.raw, out_file)
        else: print('Download failed')

# %% [markdown]
# ## Data cleaning function

# %%
def min_travel_time(filepath, travel_time_columns_list, stat_name ):
    data_dict_2015 = pyexcel.get_dict(file_name=filepath,
                            sheet_name='2015',
                            start_row=6)

    data_dict_2014 = pyexcel.get_dict(file_name=filepath,
                                sheet_name='2014',
                                start_row=6)

    df_2015 = pd.DataFrame(data_dict_2015)
    df_2014 = pd.DataFrame(data_dict_2014)
    df_2015['year'] = 2015
    df_2014['year'] = 2014
    
    df = pd.concat([df_2015, df_2014])
    # Keep only the travel time cols
    df = df[(['year', 'LSOA_code'] + travel_time_columns_list)]
    # make long - ceates columns variable and value
    df = df.melt(id_vars = ['year', 'LSOA_code'])

    def detect_mode(x):
        if 'PT' in x:
            return('public transport')
        elif 'Cyc' in x:
            return('cycle')
        elif 'Car' in x:
            return('car')
        else:
            return('NA')
        
    df['mode'] = df.variable.apply(lambda x: detect_mode(x))
    df = df[df.LSOA_code != '']
    df_output = df.set_index(['year', 'LSOA_code', 'mode']).value.rename('travel_time').reset_index().drop_duplicates()
    df_output['nearest'] = stat_name
    return(df_output)

# %% [markdown]
# ## Employment
# Travel time to employment cetnres is different to the other statistics as there are different statistics according to the size of the employment centre. I will simplify and take the minimum of the minimum travel time over the different employment centre sizes for the given mode.

# %%
def employment_min_travel_time( ):
    filepath = 'stats-spreadsheets/employment.ods'
    stat_name = 'employment_centre'
    travel_time_columns_list = ['100EmpPTt', '100EmpCyct', '100EmpCart',
                                '500EmpPTt', '500EmpCyct', '500EmpCart',
                                '5000EmpPTt', '5000EmpCyct', '5000EmpCart']
    data_dict_2015 = pyexcel.get_dict(file_name=filepath,
                            sheet_name='2015',
                            start_row=6)

    data_dict_2014 = pyexcel.get_dict(file_name=filepath,
                                sheet_name='2014',
                                start_row=6)

    df_2015 = pd.DataFrame(data_dict_2015)
    df_2014 = pd.DataFrame(data_dict_2014)
    df_2015['year'] = 2015
    df_2014['year'] = 2014
    
    df = pd.concat([df_2015, df_2014])
    # Keep only the travel time cols
    df = df[(['year', 'LSOA_code'] + travel_time_columns_list)]
    # make long - ceates columns variable and value
    df = df.melt(id_vars = ['year', 'LSOA_code'])

    def detect_mode(x):
        if 'PT' in x:
            return('public transport')
        elif 'Cyc' in x:
            return('cycle')
        elif 'Car' in x:
            return('car')
        else:
            return('NA')
        
    df['mode'] = df.variable.apply(lambda x: detect_mode(x))
    df = df[df.LSOA_code != '']
    df_output = df.groupby(['year', 'LSOA_code', 'mode']).value.min().rename('travel_time').reset_index().drop_duplicates()
    df_output['nearest'] = stat_name
    return(df_output)

# %% [markdown]
# ### LSOA meta data
# Such as local authority and region of the LSOA. Taken from the primary schools file as thats the smallest and quickest to lead

# %%
def meta_data():
    filepath = 'stats-spreadsheets/primary schools.ods'
    data_dict_2015 = pyexcel.get_dict(file_name=filepath,
                            sheet_name='2015',
                            start_row=6,
                            column_limit=4)
    df = pd.DataFrame(data_dict_2015).drop_duplicates()
    df = df[df.LSOA_code != ''] 
    return(df)

# %% [markdown]
# # Putting it together

# %%
# download_data()
emp = employment_min_travel_time()
p_school = min_travel_time('stats-spreadsheets/primary schools.ods', ['PSPTt', 'PSCyct', 'PSCart'], 'primary_school')
s_school = min_travel_time('stats-spreadsheets/secondary schools.ods', ['SSPTt', 'SSCyct', 'SSCart'], 'secondary_school')
further_ed = min_travel_time('stats-spreadsheets/further education.ods', ['FEPTt', 'FECyct', 'FECart'], 'further_education')
gp = min_travel_time('stats-spreadsheets/GP.ods', ['GPPTt', 'GPCyct', 'GPCart'], 'GP')
hospital = min_travel_time('stats-spreadsheets/hospital.ods', ['HospPTt', 'HospCyct', 'HospCart'], 'hospital')
food = min_travel_time('stats-spreadsheets/food.ods', ['FoodPTt', 'FoodCyct', 'FoodCart'], 'food')
town_centre = min_travel_time('stats-spreadsheets/town centre.ods', ['TownPTt', 'TownCyct', 'TownCart'], 'town_centre')

# %%
df = pd.concat([emp, p_school, s_school, further_ed, gp, hospital, food, town_centre], axis=0)
df_meta_data = meta_data()
df = pd.merge(df_meta_data, df, how='outer', on=['LSOA_code'])
df.to_csv('01_clean_stats.csv', index=False)

# %%
df.shape
# Out:
# (1576512, 8)

# %%
df
# Out:
#          LSOA_code      Region    LA_Code         LA_Name  year  \
# 0        E01000001      London  E09000001  City of London  2014
# 1        E01000001      London  E09000001  City of London  2014
# 2        E01000001      London  E09000001  City of London  2014
# 3        E01000001      London  E09000001  City of London  2015
# 4        E01000001      London  E09000001  City of London  2015
# 5        E01000001      London  E09000001  City of London  2015
# 6        E01000001      London  E09000001  City of London  2015
# 7        E01000001      London  E09000001  City of London  2014
# 8        E01000001      London  E09000001  City of London  2015
# 9        E01000001      London  E09000001  City of London  2014
# 10       E01000001      London  E09000001  City of London  2015
# 11       E01000001      London  E09000001  City of London  2014
# 12       E01000001      London  E09000001  City of London  2015
# 13       E01000001      London  E09000001  City of London  2014
# 14       E01000001      London  E09000001  City of London  2015
# 15       E01000001      London  E09000001  City of London  2014
# 16       E01000001      London  E09000001  City of London  2015
# 17       E01000001      London  E09000001  City of London  2014
# 18       E01000001      London  E09000001  City of London  2015
# 19       E01000001      London  E09000001  City of London  2014
# 20       E01000001      London  E09000001  City of London  2015
# 21       E01000001      London  E09000001  City of London  2014
# 22       E01000001      London  E09000001  City of London  2015
# 23       E01000001      London  E09000001  City of London  2014
# 24       E01000001      London  E09000001  City of London  2015
# 25       E01000001      London  E09000001  City of London  2014
# 26       E01000001      London  E09000001  City of London  2015
# 27       E01000001      London  E09000001  City of London  2014
# 28       E01000001      London  E09000001  City of London  2015
# 29       E01000001      London  E09000001  City of London  2014
# ...            ...         ...        ...             ...   ...
# 1576482  E01033768  North West  E08000012       Liverpool  2015
# 1576483  E01033768  North West  E08000012       Liverpool  2014
# 1576484  E01033768  North West  E08000012       Liverpool  2015
# 1576485  E01033768  North West  E08000012       Liverpool  2014
# 1576486  E01033768  North West  E08000012       Liverpool  2015
# 1576487  E01033768  North West  E08000012       Liverpool  2014
# 1576488  E01033768  North West  E08000012       Liverpool  2015
# 1576489  E01033768  North West  E08000012       Liverpool  2014
# 1576490  E01033768  North West  E08000012       Liverpool  2015
# 1576491  E01033768  North West  E08000012       Liverpool  2014
# 1576492  E01033768  North West  E08000012       Liverpool  2015
# 1576493  E01033768  North West  E08000012       Liverpool  2014
# 1576494  E01033768  North West  E08000012       Liverpool  2015
# 1576495  E01033768  North West  E08000012       Liverpool  2014
# 1576496  E01033768  North West  E08000012       Liverpool  2015
# 1576497  E01033768  North West  E08000012       Liverpool  2014
# 1576498  E01033768  North West  E08000012       Liverpool  2015
# 1576499  E01033768  North West  E08000012       Liverpool  2014
# 1576500  E01033768  North West  E08000012       Liverpool  2015
# 1576501  E01033768  North West  E08000012       Liverpool  2014
# 1576502  E01033768  North West  E08000012       Liverpool  2015
# 1576503  E01033768  North West  E08000012       Liverpool  2014
# 1576504  E01033768  North West  E08000012       Liverpool  2015
# 1576505  E01033768  North West  E08000012       Liverpool  2014
# 1576506  E01033768  North West  E08000012       Liverpool  2015
# 1576507  E01033768  North West  E08000012       Liverpool  2014
# 1576508  E01033768  North West  E08000012       Liverpool  2015
# 1576509  E01033768  North West  E08000012       Liverpool  2014
# 1576510  E01033768  North West  E08000012       Liverpool  2015
# 1576511  E01033768  North West  E08000012       Liverpool  2014
#
#                      mode travel_time            nearest
# 0                     car     6.75308  employment_centre
# 1                   cycle     6.61082  employment_centre
# 2        public transport     3.64864  employment_centre
# 3                     car     6.15341  employment_centre
# 4                   cycle     6.50175  employment_centre
# 5        public transport      3.0299  employment_centre
# 6        public transport           6     primary_school
# 7        public transport           6     primary_school
# 8                   cycle           8     primary_school
# 9                   cycle           8     primary_school
# 10                    car           7     primary_school
# 11                    car           8     primary_school
# 12       public transport      15.496   secondary_school
# 13       public transport     15.7669   secondary_school
# 14                  cycle     10.1761   secondary_school
# 15                  cycle     10.2902   secondary_school
# 16                    car     9.34774   secondary_school
# 17                    car      10.189   secondary_school
# 18       public transport     14.7634  further_education
# 19       public transport     14.9189  further_education
# 20                  cycle     9.88818  further_education
# 21                  cycle     9.96284  further_education
# 22                    car     9.34774  further_education
# 23                    car     9.78687  further_education
# 24       public transport     4.14484                 GP
# 25       public transport     3.34871                 GP
# 26                  cycle     6.69318                 GP
# 27                  cycle           6                 GP
# 28                    car     7.85715                 GP
# 29                    car     7.76872                 GP
# ...                   ...         ...                ...
# 1576482  public transport     13.9292  further_education
# 1576483  public transport     14.0158  further_education
# 1576484             cycle     9.55925  further_education
# 1576485             cycle     9.57494  further_education
# 1576486               car     8.16258  further_education
# 1576487               car     8.91043  further_education
# 1576488  public transport     3.53247                 GP
# 1576489  public transport     4.55683                 GP
# 1576490             cycle     6.49848                 GP
# 1576491             cycle     6.43707                 GP
# 1576492               car     5.95585                 GP
# 1576493               car     6.33767                 GP
# 1576494  public transport     20.5919           hospital
# 1576495  public transport      21.673           hospital
# 1576496             cycle      13.502           hospital
# 1576497             cycle     11.1915           hospital
# 1576498               car     12.5023           hospital
# 1576499               car          13           hospital
# 1576500  public transport      5.6246               food
# 1576501  public transport     5.56935               food
# 1576502             cycle     7.14199               food
# 1576503             cycle     7.16274               food
# 1576504               car     6.40444               food
# 1576505               car     6.46439               food
# 1576506  public transport     16.6487        town_centre
# 1576507  public transport     16.7698        town_centre
# 1576508             cycle     14.3013        town_centre
# 1576509             cycle     14.3153        town_centre
# 1576510               car     10.3559        town_centre
# 1576511               car     11.1909        town_centre
#
# [1576512 rows x 8 columns]

# %%
df.Region.value_counts()
# Out:
# South East                  258336
# London                      232080
# North West                  215856
# East                        173472
# West Midlands               167376
# Yorkshire and The Humber    159216
# South West                  157488
# East Midlands               133152
# North East                   79536
# Name: Region, dtype: int64

# %%
df['mode'].value_counts()
# Out:
# car                 525504
# cycle               525504
# public transport    525504
# Name: mode, dtype: int64

# %%
df.nearest.value_counts()
# Out:
# secondary_school     197064
# primary_school       197064
# further_education    197064
# food                 197064
# town_centre          197064
# employment_centre    197064
# GP                   197064
# hospital             197064
# Name: nearest, dtype: int64
